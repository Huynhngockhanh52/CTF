# %% [markdown]
# #### **Bước 1. Phân tích các phương thức có trong chương trình**
# **Bài toán:** Chúng tôi đã thực hiện nhiều thay thế để mã hóa điều này. Bạn có thể giải mã nó không? Kết nối với `nc jupiter.challenges.picoctf.org 39894`.
#
# **Hint:**
# - Flag không theo định dạng cờ thông thường

# %% [markdown]
# **Phân tích**
#
# Khi kết nối `ncat jupiter.challenges.picoctf.org 39894`, ta thu được bản mã:
# ![image.png](attachment:image.png)
#
# **Cách giải quyết**
# Sử dụng công cụ: https://www.dcode.fr/monoalphabetic-substitution để thực hiện giải mã cho nhanh.

# %%
flag = "FREQUENCY_IS_C_OVER_LAMBDA_AGFLCGTYUE"

print(flag.lower())
# Out:
# frequency_is_c_over_lambda_agflcgtyue
