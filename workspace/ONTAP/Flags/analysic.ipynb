# %% [markdown]
# #### **Bước 1. Phân tích các phương thức có trong chương trình**
# **Bài toán:** Hình ảnh trên nghĩa là gì?
#
# **Hint:**
# - Định dạng: `PICOCTF{}`

# %% [markdown]
# **Phân tích**
#
# Đây là một dạng mã hóa kỹ tự với mỗi ký tự là một flag, hình ảnh này ta chỉ có thể tính toán bằng tay. Link: https://en.wikipedia.org/wiki/International_maritime_signal_flags
#
# **Tham khảo** https://github.com/Dvd848/CTFs/blob/master/2019_picoCTF/Flags.md
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
flag = "PICOCTF{F1AG5AND5TUFF}"
